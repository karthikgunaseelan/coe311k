# %%
i=1
i = i+1
print(i)

i=2147483647
i=i+1
print(i)
# Out:
# 2
# 2147483648

# %%
j=1
j+2**-1
# Out:
# 1.5

# %%
j+2**-52
# Out:
# 1.0000000000000002

# %% [markdown]
# This is machine epsilon value (smallest value that can be added to 1 to where it's not equal to one)
